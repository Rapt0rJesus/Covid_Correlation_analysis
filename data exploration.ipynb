# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("cosesamp.csv")
dataset.head()
# Out:
#   iso_code      continent   location  total_cases  total_deaths  \
# 0      AUS        Oceania  Australia       425496          2253
# 1      CHL  South America      Chile      1806494         39115
# 2      EGY         Africa      Egypt       385575         21752
# 3      ETH         Africa   Ethiopia       420342          6937
# 4      FIN         Europe    Finland       270829          1714
#
#    total_cases_per_million  total_deaths_per_million  stringency_index  \
# 0                16499.628                    87.365             40.28
# 1                94027.689                  2035.929             35.65
# 2                 3698.266                   208.636             43.52
# 3                 3565.961                    58.850             40.74
# 4                48812.433                   308.920             34.72
#
#    population  population_density  ...  aged_65_older  gdp_per_capita  \
# 0    25788217               3.202  ...         15.504       44648.710
# ...

# %%
dataset.describe()
# Out:
#         total_cases   total_deaths  total_cases_per_million  \
# count  1.100000e+01      11.000000                11.000000
# mean   1.008724e+07  167726.454545             74200.202909
# std    1.814272e+07  268661.815429             84239.880996
# min    7.505500e+04    1714.000000              3565.961000
# 25%    4.029585e+05    4595.000000             10432.114000
# 50%    9.347410e+05   21752.000000             30551.629000
# 75%    8.472206e+06  224082.500000            129369.795500
# max    5.483508e+07  827879.000000            234872.944000
#
#        total_deaths_per_million  stringency_index    population  \
# count                 11.000000         11.000000  1.100000e+01
# mean                1235.342364         41.499091  2.016957e+08
# std                 1260.422405         10.099681  4.065329e+08
# min                   58.850000         21.300000  3.979773e+06
# 25%                  159.271500         35.420000  1.820434e+07
# ...

# %%
graph = plt.scatter(dataset['total_deaths_per_million'], dataset['total_cases_per_million'], color = 'blue')
plt.title('Cases and deaths')
plt.xlabel('Total Deaths per Million')
plt.ylabel('Total Cases per Million')
plt.show()

# %%
dataset.shape
# Out:
# (11, 21)

# %%
pearson_correlations = dataset.corr()
spearman_correlations = dataset.corr(method='spearman')
kendall_correlations = dataset.corr(method='kendall')

# %%
print(pearson_correlations["total_cases"])
# Out:
# total_cases                   1.000000
# total_deaths                  0.959894
# total_cases_per_million       0.305544
# total_deaths_per_million      0.244486
# stringency_index              0.646258
# population                    0.623628
# population_density            0.383592
# median_age                    0.190916
# aged_65_older                 0.128123
# gdp_per_capita                0.393157
# extreme_poverty              -0.058541
# cardiovasc_death_rate        -0.158770
# diabetes_prevalence           0.215499
# female_smokers                0.135186
# male_smokers                 -0.153929
# hospital_beds_per_thousand    0.018031
# life_expectancy               0.053850
# human_development_index       0.191451
# Name: total_cases, dtype: float64

# %%
print(pearson_correlations['total_deaths'])
# Out:
# total_cases                   0.959894
# total_deaths                  1.000000
# total_cases_per_million       0.247800
# total_deaths_per_million      0.322452
# stringency_index              0.559587
# population                    0.574561
# population_density            0.296557
# median_age                    0.147378
# aged_65_older                 0.057015
# gdp_per_capita                0.366948
# extreme_poverty              -0.109497
# cardiovasc_death_rate        -0.191781
# diabetes_prevalence           0.339618
# female_smokers                0.107047
# male_smokers                 -0.168573
# hospital_beds_per_thousand   -0.016764
# life_expectancy               0.043564
# human_development_index       0.190024
# Name: total_deaths, dtype: float64

# %%
print(spearman_correlations["total_cases"])
# Out:
# total_cases                   1.000000
# total_deaths                  0.918182
# total_cases_per_million       0.545455
# total_deaths_per_million      0.654545
# stringency_index              0.727273
# population                    0.627273
# population_density            0.209091
# median_age                    0.300000
# aged_65_older                 0.281818
# gdp_per_capita                0.336364
# extreme_poverty              -0.154898
# cardiovasc_death_rate        -0.336364
# diabetes_prevalence           0.372727
# female_smokers                0.496584
# male_smokers                  0.190909
# hospital_beds_per_thousand    0.141230
# life_expectancy               0.172727
# human_development_index       0.190909
# Name: total_cases, dtype: float64

# %%
print(spearman_correlations["total_deaths"])
# Out:
# total_cases                   0.918182
# total_deaths                  1.000000
# total_cases_per_million       0.354545
# total_deaths_per_million      0.618182
# stringency_index              0.690909
# population                    0.754545
# population_density            0.372727
# median_age                    0.036364
# aged_65_older                 0.000000
# gdp_per_capita                0.172727
# extreme_poverty               0.004556
# cardiovasc_death_rate        -0.100000
# diabetes_prevalence           0.618182
# female_smokers                0.264238
# male_smokers                  0.272727
# hospital_beds_per_thousand   -0.100228
# life_expectancy              -0.063636
# human_development_index      -0.063636
# Name: total_deaths, dtype: float64

# %%
print(kendall_correlations["total_cases"])
# Out:
# total_cases                   1.000000
# total_deaths                  0.781818
# total_cases_per_million       0.345455
# total_deaths_per_million      0.418182
# stringency_index              0.527273
# population                    0.454545
# population_density            0.200000
# median_age                    0.200000
# aged_65_older                 0.163636
# gdp_per_capita                0.236364
# extreme_poverty              -0.110096
# cardiovasc_death_rate        -0.236364
# diabetes_prevalence           0.309091
# female_smokers                0.330289
# male_smokers                  0.090909
# hospital_beds_per_thousand    0.073398
# life_expectancy               0.127273
# human_development_index       0.127273
# Name: total_cases, dtype: float64

# %%
print(kendall_correlations["total_deaths"])
# Out:
# total_cases                   0.781818
# total_deaths                  1.000000
# total_cases_per_million       0.200000
# total_deaths_per_million      0.418182
# stringency_index              0.527273
# population                    0.600000
# population_density            0.272727
# median_age                    0.054545
# aged_65_older                 0.018182
# gdp_per_capita                0.163636
# extreme_poverty              -0.036699
# cardiovasc_death_rate        -0.018182
# diabetes_prevalence           0.454545
# female_smokers                0.110096
# male_smokers                  0.018182
# hospital_beds_per_thousand   -0.073398
# life_expectancy              -0.018182
# human_development_index      -0.018182
# Name: total_deaths, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(pearson_correlations)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(spearman_correlations)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(kendall_correlations)
plt.show()

# %%
data_clean = dataset.iloc[:,3:]
data_clean.head()
# Out:
#    total_cases  total_deaths  total_cases_per_million  \
# 0       425496          2253                16499.628
# 1      1806494         39115                94027.689
# 2       385575         21752                 3698.266
# 3       420342          6937                 3565.961
# 4       270829          1714                48812.433
#
#    total_deaths_per_million  stringency_index  population  population_density  \
# 0                    87.365             40.28    25788217               3.202
# 1                  2035.929             35.65    19212362              24.282
# 2                   208.636             43.52   104258327              97.999
# 3                    58.850             40.74   117876226             104.957
# 4                   308.920             34.72     5548361              18.136
#
#    median_age  aged_65_older  gdp_per_capita  extreme_poverty  \
# 0        37.9         15.504       44648.710             0.50
# ...

# %%
y = data_clean.iloc[:, :1]
print(y)
# Out:
#     total_cases
# 0        425496
# 1       1806494
# 2        385575
# 3        420342
# 4        270829
# 5        934741
# 6      34861579
# 7       3979723
# 8         75055
# 9      12964690
# 10     54835075

# %%
x = data_clean.iloc[:, 4:5]
x.head()
# Out:
#    stringency_index
# 0             40.28
# 1             35.65
# 2             43.52
# 3             40.74
# 4             34.72

# %% [markdown]
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import PolynomialFeatures
# poly_reg = PolynomialFeatures(degree=2)
# x_poly = poly_reg.fit_transform(x)

# %%
lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# LinearRegression()

# %%
x_poly.shape
# Out:
# (11, 120)

# %%
plt.scatter(x, y, color= 'red')
plt.plot(x, y, color='blue')
plt.title("Poly Reg")
plt.xlabel("idk")
plt.ylabel("total cases")
plt.show()
