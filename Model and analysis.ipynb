# %% [markdown]
# # Random Forest Regression for predicting and ranking importance of various features

# %% [markdown]
# ## Importing the packages and data

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
dataset = pd.read_csv('cosesamp.csv')

# %%
dataset.head()
# Out:
#   iso_code      continent   location  total_cases  total_deaths  \
# 0      ALB         Europe    Albania       210224          3217
# 1      ARG  South America  Argentina      5654408        117169
# 2      AUS        Oceania  Australia       425496          2253
# 3      AUT         Europe    Austria      1278619         13733
# 4      BEL         Europe    Belgium      2105343         28331
#
#    total_cases_per_million  total_deaths_per_million  stringency_index  \
# 0                73173.975                  1119.761             46.30
# 1               123984.343                  2569.168             41.67
# 2                16499.628                    87.365             40.28
# 3               141392.107                  1518.621             60.19
# 4               180990.591                  2435.539             50.00
#
#    population  population_density  ...  extreme_poverty  \
# 0     2872934             104.871  ...              1.1
# ...

# %%
y = dataset['total_cases_per_million']
X = dataset.iloc[:, 7:]

# %%
X.head()
# Out:
#    stringency_index  population  population_density  median_age  \
# 0             46.30     2872934             104.871        38.0
# 1             41.67    45605823              16.177        31.9
# 2             40.28    25788217               3.202        37.9
# 3             60.19     9043072             106.749        44.4
# 4             50.00    11632334             375.564        41.8
#
#    aged_65_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0         13.188       11803.431              1.1                304.195
# 1         11.198       18933.907              0.6                191.032
# 2         15.504       44648.710              0.5                107.791
# 3         19.202       45436.686              0.7                145.183
# 4         18.571       42658.576              0.2                114.898
#
#    diabetes_prevalence  female_smokers  male_smokers  \
# 0                10.08             7.1          51.2
# ...

# %%
y.head()
# Out:
# 0     73173.975
# 1    123984.343
# 2     16499.628
# 3    141392.107
# 4    180990.591
# Name: total_cases_per_million, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=1000, max_features=4, max_depth=7,  random_state=18, max_samples=0.5)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

# %%
imp = regressor.feature_importances_
imp_percent = []
for i in imp:
    imp_percent.append(i*100)
print(imp_percent)
imp_df = np.array(imp_percent)
# Out:
# [1.9100426044072152, 5.755227612352758, 3.3683116291912416, 7.406129574356987, 6.731746345030469, 9.374220411918326, 5.372984353545748, 2.9765342636494747, 3.4736261479103727, 10.55007695209515, 2.3568812714353817, 7.680790142693052, 5.598145401669721, 15.206594474876493, 2.859624051800213, 9.379064763067408]

# %%
from sklearn import metrics
np.sqrt(metrics.mean_squared_error(y_pred, y_test))
# Out:
# 40553.776014860494
